# %%
import pandas as pd

df = pd.read_csv("datasets/dataset_oficial.csv")
df.fillna("", inplace=True)
df.head()
# Out:
#    Encuesta   Ficha     Homoclave 1.1 ¿Te parece útil esta información?  \
# 0         1  SEP517  SEP-23-002-A                                    Sí
# 1         3  SRE151  SRE-03-009-B                                    No
# 2         6  SRE144  SRE-03-007-A                                    Sí
# 3         7  SRE112    SRE-03-002                                    Sí
# 4        12  SRE113    SRE-03-003                                    No
#
#   1.2 ¿Consideras que falta información?  \
# 0                                     No
# 1                                     Sí
# 2                                     Sí
# 3                                     No
# 4                                     Sí
#
#                1.3 ¿Qué información crees que falta?  \
# 0
# 1  Las citas vía Internet antes las podía hacer a...
# 2  LA INFORMACIÓN DE LAS CITAS NO ESTA AL ALCANCE...
# 3
# 4  no se puede agendar la cita para la renovación...
#
#                            1.4 ¿Qué podemos mejorar?       Fecha  \
# 0  los documentos se puedan entregar de forma ele...  2015-12-23
# 1  Seria mejor el sistema anterior donde se podía...  2015-12-23
# 2  PRESENTEN LA INFORMACIÓN PARA HACER CITAS DE F...  2015-12-23
# 3  Poder agendar cita por Internet , eso sería de...  2015-12-23
# 4  la página esta saturada de información que no ...  2015-12-25
#
#   Sentimiento 1  Sentimiento 2  \
# 0             1              1
# 1             1              1
# 2             0              1
# 3             1              2
# 4             0              1
#
#                                           1.3 Inglés  \
# 0
# 1  Appointments via the Internet before now I cou...
# 2  INFORMATION APPOINTMENTS TO THE EXTENT NOT, IT...
# 3
# 4  You can not schedule the appointment for passp...
#
#                                           1.4 Inglés
# 0          documents can be delivered electronically
# 1  It would better the previous system where you ...
# 2         INFORMATION PRESENTED TO DATING FORM CLARA
# 3  To schedule appointment online, that would be ...
# 4  page is saturated with information that is not...

# %% [markdown]
# ## Rename columns

# %%
df.columns = ["poll_id", "token", "institution", "is_info_useful", "is_info_missing", "missing_info", 
              "improvements", "date", "missing_info_sentiment", "improvements_sentiment",
              "missing_info_en", "improvements_en"]
df.head()
# Out:
#    poll_id   token   institution is_info_useful is_info_missing  \
# 0        1  SEP517  SEP-23-002-A             Sí              No
# 1        3  SRE151  SRE-03-009-B             No              Sí
# 2        6  SRE144  SRE-03-007-A             Sí              Sí
# 3        7  SRE112    SRE-03-002             Sí              No
# 4       12  SRE113    SRE-03-003             No              Sí
#
#                                         missing_info  \
# 0
# 1  Las citas vía Internet antes las podía hacer a...
# 2  LA INFORMACIÓN DE LAS CITAS NO ESTA AL ALCANCE...
# 3
# 4  no se puede agendar la cita para la renovación...
#
#                                         improvements        date  \
# 0  los documentos se puedan entregar de forma ele...  2015-12-23
# 1  Seria mejor el sistema anterior donde se podía...  2015-12-23
# 2  PRESENTEN LA INFORMACIÓN PARA HACER CITAS DE F...  2015-12-23
# 3  Poder agendar cita por Internet , eso sería de...  2015-12-23
# 4  la página esta saturada de información que no ...  2015-12-25
#
#   missing_info_sentiment  improvements_sentiment  \
# 0                      1                       1
# 1                      1                       1
# 2                      0                       1
# 3                      1                       2
# 4                      0                       1
#
#                                      missing_info_en  \
# 0
# 1  Appointments via the Internet before now I cou...
# 2  INFORMATION APPOINTMENTS TO THE EXTENT NOT, IT...
# 3
# 4  You can not schedule the appointment for passp...
#
#                                      improvements_en
# 0          documents can be delivered electronically
# 1  It would better the previous system where you ...
# 2         INFORMATION PRESENTED TO DATING FORM CLARA
# 3  To schedule appointment online, that would be ...
# 4  page is saturated with information that is not...

# %% [markdown]
# ## Remove empty data

# %%
na_filter = df["missing_info"].isna() & df["improvements"].isna()
df[na_filter]
# Out:
# Empty DataFrame
# Columns: [poll_id, token, institution, is_info_useful, is_info_missing, missing_info, improvements, date, missing_info_sentiment, improvements_sentiment, missing_info_en, improvements_en]
# Index: []

# %%
df = df[~na_filter]
print(df[na_filter])
# Out:
# Empty DataFrame
# Columns: [poll_id, token, institution, is_info_useful, is_info_missing, missing_info, improvements, date, missing_info_sentiment, improvements_sentiment, missing_info_en, improvements_en]
# Index: []

# %% [markdown]
# ## Data transformation

# %%
## Transform is_info_useful to boolean values
df["is_info_useful"] = df["is_info_useful"].map({"Sí": 1, "No": 0})
df["is_info_useful"].value_counts()
# Out:
# 1    4098
# 0    2836
# Name: is_info_useful, dtype: int64

# %% [markdown]
# ## Create train set

# %%
not_labeled = df["missing_info_sentiment"]==""
df_train = df.loc[~not_labeled]
df_train.head()
# Out:
#    poll_id   token   institution  is_info_useful is_info_missing  \
# 0        1  SEP517  SEP-23-002-A               1              No
# 1        3  SRE151  SRE-03-009-B               0              Sí
# 2        6  SRE144  SRE-03-007-A               1              Sí
# 3        7  SRE112    SRE-03-002               1              No
# 4       12  SRE113    SRE-03-003               0              Sí
#
#                                         missing_info  \
# 0
# 1  Las citas vía Internet antes las podía hacer a...
# 2  LA INFORMACIÓN DE LAS CITAS NO ESTA AL ALCANCE...
# 3
# 4  no se puede agendar la cita para la renovación...
#
#                                         improvements        date  \
# 0  los documentos se puedan entregar de forma ele...  2015-12-23
# 1  Seria mejor el sistema anterior donde se podía...  2015-12-23
# 2  PRESENTEN LA INFORMACIÓN PARA HACER CITAS DE F...  2015-12-23
# 3  Poder agendar cita por Internet , eso sería de...  2015-12-23
# 4  la página esta saturada de información que no ...  2015-12-25
#
#   missing_info_sentiment  improvements_sentiment  \
# 0                      1                       1
# 1                      1                       1
# 2                      0                       1
# 3                      1                       2
# 4                      0                       1
#
#                                      missing_info_en  \
# 0
# 1  Appointments via the Internet before now I cou...
# 2  INFORMATION APPOINTMENTS TO THE EXTENT NOT, IT...
# 3
# 4  You can not schedule the appointment for passp...
#
#                                      improvements_en
# 0          documents can be delivered electronically
# 1  It would better the previous system where you ...
# 2         INFORMATION PRESENTED TO DATING FORM CLARA
# 3  To schedule appointment online, that would be ...
# 4  page is saturated with information that is not...

# %%
df_train.shape[0]
# Out:
# 3104

# %% [markdown]
# ### Remove tildes

# %%
df_train.loc[:, "missing_info"] = df_train["missing_info"].astype(str)
df_train.loc[:, "improvements"] = df_train["improvements"].astype(str)
df_train.loc[:, "missing_info_en"] = df_train["missing_info_en"].astype(str)
df_train.loc[:, "improvements_en"] = df_train["improvements_en"].astype(str)
# Out:
# /home/julio/.local/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
import re
import string

#--------------------------------------------------
punctuations = list(string.punctuation)
def listToDict(lst):
    return {lst[i]: '' for i in range(0, len(lst), 2)}

punctuations =  listToDict(punctuations)
#--------------------------------------------------

def clean(string):
    if string in ["nan", "#VALUE!"]:
        return ""
    string = string.lower()
    
    #Remove tildes
    vocales = {"á": "a", "é": "e", "í": "i", "ó": "o", "ú": "u"}
    for vocal in vocales.keys():
        string = string.replace(vocal, vocales[vocal])
    
    #Remove non-alphanumeric characters
    for punctuation in punctuations.keys():
        string = string.replace(punctuation, punctuations[punctuation])
    
    #Remove punctuation
    string = re.sub(r'[^(a-zA-Z)\s]','', string)
    return string

# %%
df_train.loc[:, 'missing_info'] =  df_train['missing_info'].apply(lambda x: clean(x))
df_train.loc[:, 'improvements'] =  df_train['improvements'].apply(lambda x: clean(x))
df_train.loc[:, 'missing_info_en'] =  df_train['missing_info_en'].apply(lambda x: clean(x))
df_train.loc[:, 'improvements_en'] =  df_train['improvements_en'].apply(lambda x: clean(x))

# %%
df_train.head()
# Out:
#    poll_id   token   institution  is_info_useful is_info_missing  \
# 0        1  SEP517  SEP-23-002-A               1              No
# 1        3  SRE151  SRE-03-009-B               0              Sí
# 2        6  SRE144  SRE-03-007-A               1              Sí
# 3        7  SRE112    SRE-03-002               1              No
# 4       12  SRE113    SRE-03-003               0              Sí
#
#                                         missing_info  \
# 0
# 1  las citas via internet antes las podia hacer a...
# 2  la informacion de las citas no esta al alcance...
# 3
# 4  no se puede agendar la cita para la renovacion...
#
#                                         improvements        date  \
# 0  los documentos se puedan entregar de forma ele...  2015-12-23
# 1  seria mejor el sistema anterior donde se podia...  2015-12-23
# 2  presenten la informacion para hacer citas de f...  2015-12-23
# 3  poder agendar cita por internet  eso seria de ...  2015-12-23
# 4  la pagina esta saturada de informacion que no ...  2015-12-25
#
#   missing_info_sentiment  improvements_sentiment  \
# 0                      1                       1
# 1                      1                       1
# 2                      0                       1
# 3                      1                       2
# 4                      0                       1
#
#                                      missing_info_en  \
# 0
# 1  appointments via the internet before now i cou...
# 2  information appointments to the extent not it ...
# 3
# 4  you can not schedule the appointment for passp...
#
#                                      improvements_en
# 0          documents can be delivered electronically
# 1  it would better the previous system where you ...
# 2         information presented to dating form clara
# 3  to schedule appointment online that would be v...
# 4  page is saturated with information that is not...

# %% [markdown]
# ## Tokenizing and removing stop words

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/julio/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def remove_stop_words(string, language):
    # Create dictionary of stopwords for spanish and english
    stopwords_dict = {
        "es": list(set(stopwords.words('spanish'))),
        "en": list(set(stopwords.words('english')))
    }
    # tokenize 
    tokenized = word_tokenize(string)
    # remove stopwords 
    stopped = [w for w in tokenized if not w in stopwords_dict[language]]
    # join the list of above words to create a sentence without stop words
    filtered_string = (" ").join(stopped)
    return filtered_string

# %%
df_train.loc[:, 'missing_info_wo_stop_words'] =  df['missing_info'].apply(lambda x: remove_stop_words(x, 'es'))
df_train.loc[:, 'improvements_wo_stop_words'] =  df['improvements'].apply(lambda x: remove_stop_words(x, 'es'))
df_train.loc[:, 'missing_info_en_wo_stop_words'] =  df['missing_info_en'].apply(lambda x: remove_stop_words(x, 'en'))
df_train.loc[:, 'improvements_en_wo_stop_words'] =  df['improvements_en'].apply(lambda x: remove_stop_words(x, 'en'))
# Out:
# /home/julio/.local/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/julio/.local/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_train.head()
# Out:
#    poll_id   token   institution  is_info_useful is_info_missing  \
# 0        1  SEP517  SEP-23-002-A               1              No
# 1        3  SRE151  SRE-03-009-B               0              Sí
# 2        6  SRE144  SRE-03-007-A               1              Sí
# 3        7  SRE112    SRE-03-002               1              No
# 4       12  SRE113    SRE-03-003               0              Sí
#
#                                         missing_info  \
# 0
# 1  las citas via internet antes las podia hacer a...
# 2  la informacion de las citas no esta al alcance...
# 3
# 4  no se puede agendar la cita para la renovacion...
#
#                                         improvements        date  \
# 0  los documentos se puedan entregar de forma ele...  2015-12-23
# 1  seria mejor el sistema anterior donde se podia...  2015-12-23
# 2  presenten la informacion para hacer citas de f...  2015-12-23
# 3  poder agendar cita por internet  eso seria de ...  2015-12-23
# 4  la pagina esta saturada de informacion que no ...  2015-12-25
#
#   missing_info_sentiment  improvements_sentiment  \
# 0                      1                       1
# 1                      1                       1
# 2                      0                       1
# 3                      1                       2
# 4                      0                       1
#
#                                      missing_info_en  \
# 0
# 1  appointments via the internet before now i cou...
# 2  information appointments to the extent not it ...
# 3
# 4  you can not schedule the appointment for passp...
#
#                                      improvements_en  \
# 0          documents can be delivered electronically
# 1  it would better the previous system where you ...
# 2         information presented to dating form clara
# 3  to schedule appointment online that would be v...
# 4  page is saturated with information that is not...
#
#                           missing_info_wo_stop_words  \
# 0
# 1  Las citas vía Internet podía hacer ahora resul...
# 2  LA INFORMACIÓN DE LAS CITAS NO ESTA AL ALCANCE...
# 3
# 4  puede agendar cita renovación pasaporte ... ni...
#
#                           improvements_wo_stop_words  \
# 0       documentos puedan entregar forma electrónica
# 1  Seria mejor sistema anterior podía hacer cita ...
# 2  PRESENTEN LA INFORMACIÓN PARA HACER CITAS DE F...
# 3       Poder agendar cita Internet , mucha utilidad
# 4  página saturada información util ... . q neces...
#
#                        missing_info_en_wo_stop_words  \
# 0
# 1  Appointments via Internet I could make impossi...
# 2  INFORMATION APPOINTMENTS TO THE EXTENT NOT , I...
# 3
# 4  You schedule appointment passport renewal ... ...
#
#                        improvements_en_wo_stop_words
# 0                 documents delivered electronically
# 1  It would better previous system could make app...
# 2         INFORMATION PRESENTED TO DATING FORM CLARA
# 3      To schedule appointment online , would useful
# 4  page saturated information useful ... . q need...

# %% [markdown]
# ## NLTK Part of Speech (POS)

# %%
# Run only once
import stanfordnlp

# stanfordnlp.download('es')   # This downloads the Spanish models for the neural pipeline
# stanfordnlp.download('en')   # This downloads the English models for the neural pipeline

# %%
# MODELS_DIR = "/home/omar/Documentos/S_AI/Equipo_4/stanford_tagger/stanfordnlp_resources"
MODELS_DIR = "/home/julio/stanfordnlp_resources"

# This sets up a default neural pipeline
nlp_es = stanfordnlp.Pipeline(lang='es', models_dir=MODELS_DIR, processors = "tokenize,mwt,lemma,pos", use_gpu=True)
nlp_en = stanfordnlp.Pipeline(lang='en', models_dir=MODELS_DIR, processors = "tokenize,mwt,lemma,pos")
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/es_ancora_models/es_ancora_tokenizer.pt', 'lang': 'es', 'shorthand': 'es_ancora', 'mode': 'predict'}
# ---
# Loading: mwt
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/es_ancora_models/es_ancora_mwt_expander.pt', 'lang': 'es', 'shorthand': 'es_ancora', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/es_ancora_models/es_ancora_lemmatizer.pt', 'lang': 'es', 'shorthand': 'es_ancora', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/es_ancora_models/es_ancora_tagger.pt', 'pretrain_path': '/home/julio/stanfordnlp_resources/es_ancora_models/es_ancora.pretrain.pt', 'lang': 'es', 'shorthand': 'es_ancora', 'mode': 'predict'}
# Done loading processors!
# ---
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/julio/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/home/julio/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %% [markdown]
# ## Create Bag of words with POS

# %%
# dictionary to hold pos tags and their explanations
pos_dict = {
'CC': 'coordinating conjunction',
'CD': 'cardinal digit',
'DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word',
'IN':  'preposition/subordinating conjunction',
'JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'',
'JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)',
'MD': 'modal could, will',
'NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'',
'NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'',
'PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s',
'PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers',
'RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better',
'RBS': 'adverb, superlative best',
'RP': 'particle give up',
'TO': 'to go \'to\' the store.',
'UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take',
'VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking',
'VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take',
'VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which',
'WP': 'wh-pronoun who, what',
'WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when',
'QF' : 'quantifier, bahut, thoda, kam (Hindi)',
'VM' : 'main verb',
'PSP' : 'postposition, common in indian langs',
'DEM' : 'demonstrative, common in indian langs'
}

def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    return pd.DataFrame(parsed_text)

# %%
# Function to extract either only adjectives or noun plus adjectives
def extract_adj_noun(txt, language="en", noun=False):
    if language == "es":
        corpus = nlp_es(txt)
    else:
        corpus = nlp_en(txt)
    BOW = extract_pos(corpus)
    adj_pos = ["ADJ", "JJ", "JJR", "JJS"]
    noun_pos = ["NOUN", "NN", "NNS", "NNP", "NNPS"]
    if noun:
        return " ".join(BOW[BOW["pos"].isin(adj_pos + noun_pos)]["word"])
    return " ".join(BOW[BOW["pos"].isin(adj_pos)]["word"])

# %%
# Get spanish adjectives and nouns + adjectives
df_train.loc[:, "missing_info_adj"] = df_train["missing_info_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'es') if x != "" else "")
df_train.loc[:, "improvements_adj"] = df_train["improvements_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'es') if x != "" else "")
df_train.loc[:, "missing_info_noun_adj"] = df_train["missing_info_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'es', True) if x != "" else "")
df_train.loc[:, "improvements_noun_adj"] = df_train["improvements_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'es', True) if x != "" else "")

# %%
# Get english adjectives and nouns + adjectives
df_train.loc[:, "missing_info_en_adj"] = df_train["missing_info_en_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'en') if x != "" else "")
df_train.loc[:, "improvements_en_adj"] = df_train["improvements_en_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'en') if x != "" else "")
df_train.loc[:, "missing_info_en_noun_adj"] = df_train["missing_info_en_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'en', True) if x != "" else "")
df_train.loc[:, "improvements_en_noun_adj"] = df_train["improvements_en_wo_stop_words"].apply(lambda x: extract_adj_noun(x, 'en', True) if x != "" else "")
